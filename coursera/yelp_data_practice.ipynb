# %%
import pandas as pd
xls = pd.ExcelFile('yelp.xlsx')
df = xls.parse('yelp_data')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
df.head()
# Out:
#                            name   category_0       category_1  take_out  \
# 0  China Sea Chinese Restaurant  Restaurants          Chinese      True
# 1          Discount Tire Center        Tires       Automotive     False
# 2                  Frankfurters  Restaurants         Hot Dogs      True
# 3             Fred Dietz Floral     Shopping  Flowers & Gifts     False
# 4                 Kuhn's Market         Food          Grocery     False
#
#    review_count  stars  city_id  state_id
# 0            11    2.5        1         1
# 1            24    4.5        1         1
# 2             3    4.5        1         1
# 3             6    4.0        1         1
# 4             8    3.5        1         1

# %%
df_cities = xls.parse('cities')
df_cities.head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#    id           city
# 0   1       Bellevue
# 1   2       Braddock
# 2   3       Carnegie
# 3   4      Homestead
# 4   5  Mc Kees Rocks

# %%
df_states =xls.parse('states')
df_states.head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#    id state
# 0   1    PA
# 1   2    NV

# %%
df = pd.merge(left = df, right = df_cities, how = 'inner', left_on='city_id', right_on='id')

# %%
df.head()
# Out:
#                            name   category_0       category_1  take_out  \
# 0  China Sea Chinese Restaurant  Restaurants          Chinese      True
# 1          Discount Tire Center        Tires       Automotive     False
# 2                  Frankfurters  Restaurants         Hot Dogs      True
# 3             Fred Dietz Floral     Shopping  Flowers & Gifts     False
# 4                 Kuhn's Market         Food          Grocery     False
#
#    review_count  stars  city_id  state_id  id      city
# 0            11    2.5        1         1   1  Bellevue
# 1            24    4.5        1         1   1  Bellevue
# 2             3    4.5        1         1   1  Bellevue
# 3             6    4.0        1         1   1  Bellevue
# 4             8    3.5        1         1   1  Bellevue

# %%
df = pd.merge(left = df, right = df_states, how = 'inner', left_on='state_id', right_on='id')

# %%
df.head()
# Out:
#                            name   category_0       category_1  take_out  \
# 0  China Sea Chinese Restaurant  Restaurants          Chinese      True
# 1          Discount Tire Center        Tires       Automotive     False
# 2                  Frankfurters  Restaurants         Hot Dogs      True
# 3             Fred Dietz Floral     Shopping  Flowers & Gifts     False
# 4                 Kuhn's Market         Food          Grocery     False
#
#    review_count  stars  city_id  state_id  id_x      city  id_y state
# 0            11    2.5        1         1     1  Bellevue     1    PA
# 1            24    4.5        1         1     1  Bellevue     1    PA
# 2             3    4.5        1         1     1  Bellevue     1    PA
# 3             6    4.0        1         1     1  Bellevue     1    PA
# 4             8    3.5        1         1     1  Bellevue     1    PA

# %%
atts = ['name','city','state']
df[atts].head(100)
# Out:
#                                               name        city state
# 0                     China Sea Chinese Restaurant    Bellevue    PA
# 1                             Discount Tire Center    Bellevue    PA
# 2                                     Frankfurters    Bellevue    PA
# 3                                Fred Dietz Floral    Bellevue    PA
# 4                                    Kuhn's Market    Bellevue    PA
# ..                                             ...         ...   ...
# 95                             Aamco Transmissions  Pittsburgh    PA
# 96  Animal Rescue League Shelter & Wildlife Center  Pittsburgh    PA
# 97                          Aracri's Greentree Inn  Pittsburgh    PA
# 98                           Atch-Mont Real Estate  Pittsburgh    PA
# 99                              Atria's Restaurant  Pittsburgh    PA
#
# [100 rows x 3 columns]

# %%
del df['id_x']

# %%
del df['id_y']

# %%
df.head()
# Out:
#                            name   category_0       category_1  take_out  \
# 0  China Sea Chinese Restaurant  Restaurants          Chinese      True
# 1          Discount Tire Center        Tires       Automotive     False
# 2                  Frankfurters  Restaurants         Hot Dogs      True
# 3             Fred Dietz Floral     Shopping  Flowers & Gifts     False
# 4                 Kuhn's Market         Food          Grocery     False
#
#    review_count  stars  city_id  state_id      city state
# 0            11    2.5        1         1  Bellevue    PA
# 1            24    4.5        1         1  Bellevue    PA
# 2             3    4.5        1         1  Bellevue    PA
# 3             6    4.0        1         1  Bellevue    PA
# 4             8    3.5        1         1  Bellevue    PA

# %%
df[100:200]
# Out:
#                                        name      category_0  \
# 100                          Au Bon Pain Co            Food
# 101        Bado's Pizza Grill and Ale House         Italian
# 102                    Bastone Auto Service     Auto Repair
# 103               Bellisario's Pizza Palace         Italian
# 104  Benedum Center for the Performing Arts  Opera & Ballet
# ..                                      ...             ...
# 195                              McDonald's         Burgers
# 196                     Miller Ace Hardware        Shopping
# 197         Minutello's Restaurant & Lounge         Italian
# 198           Monro Muffler Brake & Service           Tires
# 199                           Moonlite Cafe     Restaurants
#
#                category_1  take_out  review_count  stars  city_id  state_id  \
# 100              Bakeries     False             7    3.0        8         1
# 101                  Bars      True            93    3.5        8         1
# 102            Automotive     False            20    4.0        8         1
# 103                 Pizza      True            21    3.5        8         1
# 104  Arts & Entertainment     False            56    4.5        8         1
# ..                    ...       ...           ...    ...      ...       ...
# 195             Fast Food      True             5    2.0        8         1
# 196       Hardware Stores     False             5    4.5        8         1
# 197                 Pizza      True             8    3.0        8         1
# 198            Automotive     False             9    2.0        8         1
# 199               Italian      True            20    4.5        8         1
#
#            city state
# 100  Pittsburgh    PA
# 101  Pittsburgh    PA
# 102  Pittsburgh    PA
# 103  Pittsburgh    PA
# 104  Pittsburgh    PA
# ..          ...   ...
# 195  Pittsburgh    PA
# 196  Pittsburgh    PA
# 197  Pittsburgh    PA
# 198  Pittsburgh    PA
# 199  Pittsburgh    PA
#
# [100 rows x 10 columns]

# %%
index = len(df) - 1

last_business = df[index:]

last_business['name']
# Out:
# 599    A Sunrise Towing
# Name: name, dtype: object

# %%
df[-1:]['name']
# Out:
# 599    A Sunrise Towing
# Name: name, dtype: object

# %%
pitts = df['city'] == 'Pittsburgh'

type(pitts)
# Out:
# pandas.core.series.Series

# %%
pitts
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 595    False
# 596    False
# 597    False
# 598    False
# 599    False
# Name: city, Length: 600, dtype: bool

# %%
df[pitts]
# Out:
#                                                name            category_0  \
# 95                              Aamco Transmissions           Auto Repair
# 96   Animal Rescue League Shelter & Wildlife Center       Animal Shelters
# 97                           Aracri's Greentree Inn               Italian
# 98                            Atch-Mont Real Estate  Real Estate Services
# 99                               Atria's Restaurant        American (New)
# ..                                              ...                   ...
# 283                             Walter's Automotive           Auto Repair
# 284                     Washington's Landing Marina           Active Life
# 285                             West Liberty Cycles        Sporting Goods
# 286                                  Wiseguys Pizza           Restaurants
# 287                                     X Shadyside           Active Life
#
#               category_1  take_out  review_count  stars  city_id  state_id  \
# 95            Automotive     False            21    4.5        8         1
# 96         Veterinarians     False            43    4.0        8         1
# 97        American (New)      True            15    3.5        8         1
# 98   Property Management     False             3    2.0        8         1
# 99            Sandwiches      True            69    3.0        8         1
# ..                   ...       ...           ...    ...      ...       ...
# 283           Automotive     False            99    5.0        8         1
# 284              Boating     False             3    3.0        8         1
# 285                Bikes     False             8    4.5        8         1
# 286                Pizza      True            12    3.0        8         1
# 287                 Yoga     False            31    3.5        8         1
#
#            city state
# 95   Pittsburgh    PA
# 96   Pittsburgh    PA
# 97   Pittsburgh    PA
# 98   Pittsburgh    PA
# 99   Pittsburgh    PA
# ..          ...   ...
# 283  Pittsburgh    PA
# 284  Pittsburgh    PA
# 285  Pittsburgh    PA
# 286  Pittsburgh    PA
# 287  Pittsburgh    PA
#
# [193 rows x 10 columns]

# %%
rest = df['name'] == 'The Dragon Chinese Cuisine'
df[rest]
# Out:
#                           name   category_0 category_1  take_out  \
# 93  The Dragon Chinese Cuisine  Restaurants    Chinese      True
#
#     review_count  stars  city_id  state_id     city state
# 93             7    3.0        7         1  Munhall    PA

# %%
df[rest]['take_out']
# Out:
# 93    True
# Name: take_out, dtype: bool

# %%
cat_0_bars = df['category_0'] == 'Bars'
cat_1_bars = df['category_1'] == 'Bars'

df[cat_0_bars | cat_1_bars]
# Out:
#                                  name   category_0              category_1  \
# 12                      Emil's Lounge         Bars          American (New)
# 15              Alexion's Bar & Grill         Bars  American (Traditional)
# 32                     Rocky's Lounge         Bars  American (Traditional)
# 42             Duke's Upper Deck Cafe         Pubs                    Bars
# 62            Randy's Beer Barrel Pub         Pubs                    Bars
# 70                        TGI Fridays         Bars  American (Traditional)
# 77                         Applebee's         Bars  American (Traditional)
# 101  Bado's Pizza Grill and Ale House      Italian                    Bars
# 114                     Buffalo Blues  Restaurants                    Bars
# 119                      Cappy's Cafe         Bars  American (Traditional)
# 138                       Doc's Place         Bars                   Pizza
# 171                            Huddle         Bars  American (Traditional)
# 187                     Le Mardi Gras         Food                    Bars
# 203                       Mt Troy Inn         Bars               Nightlife
# 209              Nico's Recovery Room         Bars  American (Traditional)
# 232                    Primanti Bros.  Restaurants                    Bars
# 233                   Pub In the Park         Pubs                    Bars
# 272                    The Korner Pub         Pubs                    Bars
# 274                    The Park House         Pubs                    Bars
# 279                Tramp's Restaurant         Bars  American (Traditional)
# 288                         Bar Louie         Bars          American (New)
# 300                Buffalo Wild Wings         Bars  American (Traditional)
# 433                      Boomer's Bar         Bars  American (Traditional)
# 450                   Hard Hat Lounge    Dive Bars                    Bars
# 451                  Huntridge Tavern    Dive Bars                    Bars
# 452                        Jack's Pub         Pubs                    Bars
# 453                      Moon Doggies    Dive Bars                    Bars
# 515                        Jake's Bar         Bars               Nightlife
# 593            Sporting Chance Saloon         Bars               Nightlife
#
#      take_out  review_count  stars  city_id  state_id             city state
# 12       True            26    4.5        2         1         Braddock    PA
# 15       True            23    4.0        3         1         Carnegie    PA
# 32       True            10    4.0        3         1         Carnegie    PA
# 42       True            33    3.5        4         1        Homestead    PA
# 62      False             3    2.5        4         1        Homestead    PA
# 70       True            23    2.5        4         1        Homestead    PA
# 77       True             9    3.5        5         1    Mc Kees Rocks    PA
# 101      True            93    3.5        8         1       Pittsburgh    PA
# 114      True            62    3.0        8         1       Pittsburgh    PA
# 119      True            51    3.0        8         1       Pittsburgh    PA
# 138      True            21    3.0        8         1       Pittsburgh    PA
# 171      True            17    4.0        8         1       Pittsburgh    PA
# 187     False            48    4.0        8         1       Pittsburgh    PA
# 203     False             3    3.5        8         1       Pittsburgh    PA
# 209      True            24    3.5        8         1       Pittsburgh    PA
# 232      True           463    3.5        8         1       Pittsburgh    PA
# 233     False             6    4.5        8         1       Pittsburgh    PA
# 272     False             8    4.5        8         1       Pittsburgh    PA
# 274      True            61    4.0        8         1       Pittsburgh    PA
# 279      True             4    3.5        8         1       Pittsburgh    PA
# 288      True            92    2.5        9         1   West Homestead    PA
# 300      True           171    3.0       11         2        Henderson    NV
# 433     False            19    3.5       12         2        Las Vegas    NV
# 450     False            31    3.5       12         2        Las Vegas    NV
# 451     False            50    4.0       12         2        Las Vegas    NV
# 452     False            20    2.5       12         2        Las Vegas    NV
# 453     False            85    4.0       12         2        Las Vegas    NV
# 515     False            12    4.5       12         2        Las Vegas    NV
# 593     False             7    3.5       13         2  North Las Vegas    NV

# %%
carnegie = df['city'] == 'Carnegie'

df[(cat_0_bars | cat_1_bars) & carnegie]
# Out:
#                      name category_0              category_1  take_out  \
# 15  Alexion's Bar & Grill       Bars  American (Traditional)      True
# 32         Rocky's Lounge       Bars  American (Traditional)      True
#
#     review_count  stars  city_id  state_id      city state
# 15            23    4.0        3         1  Carnegie    PA
# 32            10    4.0        3         1  Carnegie    PA

# %%
cat_0 = df['category_0'].isin(["Bars", "Restaurants"])
cat_1 = df['category_1'].isin(["Bars", "Restaurants"])
df[(cat_0 | cat_1) & carnegie]
# Out:
#                             name   category_0              category_1  \
# 15         Alexion's Bar & Grill         Bars  American (Traditional)
# 18  Barb's Country Junction Cafe  Restaurants                   Cafes
# 20    Don Don Chinese Restaurant  Restaurants                 Chinese
# 29                      Papa J's  Restaurants                 Italian
# 30    Porto Fino Pizzaria & Gyro  Restaurants                   Pizza
# 32                Rocky's Lounge         Bars  American (Traditional)
#
#     take_out  review_count  stars  city_id  state_id      city state
# 15      True            23    4.0        3         1  Carnegie    PA
# 18      True             9    4.0        3         1  Carnegie    PA
# 20      True            10    2.5        3         1  Carnegie    PA
# 29      True            81    3.5        3         1  Carnegie    PA
# 30     False             4    2.5        3         1  Carnegie    PA
# 32      True            10    4.0        3         1  Carnegie    PA

# %%
cat_0_dbars = df['category_0'] == 'Dive Bars'
cat_1_dbars = df['category_1'] == 'Dive Bars'
las_vegas = df['city'] == 'Las Vegas'
at_least_4s = df['stars'] >= 4.0

db_4s = df[(cat_0_dbars | cat_1_dbars) & las_vegas & at_least_4s]

# %%
import random

# %%
rand = random.randint(0, len(db_4s) - 1)
random_db_4s_1 = db_4s[rand: rand + 1]
random_db_4s_1
# Out:
#              name category_0 category_1  take_out  review_count  stars  \
# 453  Moon Doggies  Dive Bars       Bars     False            85    4.0
#
#      city_id  state_id       city state
# 453       12         2  Las Vegas    NV

# %%
rand = random.randint(0, len(db_4s) - 1)
random_db_4s_2 = db_4s.iloc[rand]
random_db_4s_2
# Out:
# name            Moon Doggies
# category_0         Dive Bars
# category_1              Bars
# take_out               False
# review_count              85
# stars                    4.0
# city_id                   12
# state_id                   2
# city               Las Vegas
# state                     NV
# Name: 453, dtype: object

# %%
cat_0_ns = df['category_0'].str.contains("Nail Salon")
cat_1_ns = df['category_1'].str.contains("Nail Salon")
henderson = df['city'] == 'Henderson'

df[(cat_0_ns | cat_1_ns) & henderson]['review_count'].sum()
# Out:
# 158

# %%
cat_0_ar = df['category_0'].str.contains("Auto Repair")
cat_1_ar = df['category_1'].str.contains("Auto Repair")

df[(cat_0_ar | cat_1_ar) & pitts]['stars'].mean()
# Out:
# 4.5

# %%
df['rating'] = df['stars']*2

# %%
df.head()
# Out:
#                            name   category_0       category_1  take_out  \
# 0  China Sea Chinese Restaurant  Restaurants          Chinese      True
# 1          Discount Tire Center        Tires       Automotive     False
# 2                  Frankfurters  Restaurants         Hot Dogs      True
# 3             Fred Dietz Floral     Shopping  Flowers & Gifts     False
# 4                 Kuhn's Market         Food          Grocery     False
#
#    review_count  stars  city_id  state_id      city state  rating
# 0            11    2.5        1         1  Bellevue    PA     5.0
# 1            24    4.5        1         1  Bellevue    PA     9.0
# 2             3    4.5        1         1  Bellevue    PA     9.0
# 3             6    4.0        1         1  Bellevue    PA     8.0
# 4             8    3.5        1         1  Bellevue    PA     7.0

# %%
def convert_to_rating(x):
    return(str(x) + " out of 10")

df['rating'] = df['rating'].apply(convert_to_rating)

# %%
df.head()
# Out:
#                            name   category_0       category_1  take_out  \
# 0  China Sea Chinese Restaurant  Restaurants          Chinese      True
# 1          Discount Tire Center        Tires       Automotive     False
# 2                  Frankfurters  Restaurants         Hot Dogs      True
# 3             Fred Dietz Floral     Shopping  Flowers & Gifts     False
# 4                 Kuhn's Market         Food          Grocery     False
#
#    review_count  stars  city_id  state_id      city state         rating
# 0            11    2.5        1         1  Bellevue    PA  5.0 out of 10
# 1            24    4.5        1         1  Bellevue    PA  9.0 out of 10
# 2             3    4.5        1         1  Bellevue    PA  9.0 out of 10
# 3             6    4.0        1         1  Bellevue    PA  8.0 out of 10
# 4             8    3.5        1         1  Bellevue    PA  7.0 out of 10

# %%
df[len(df) - 1 : ]
# Out:
#                  name  category_0 category_1  take_out  review_count  stars  \
# 599  A Sunrise Towing  Automotive     Towing     False             4    1.0
#
#      city_id  state_id             city state         rating
# 599       13         2  North Las Vegas    NV  2.0 out of 10

# %%
type(pitts)
# Out:
# pandas.core.series.Series

# %%
bars_rest = df["category_0"].isin(["Bars", "Restaurants"])
df_bars_rest = df[bars_rest]

# %%
pivot_state_cat = pd.pivot_table(df_bars_rest, index = ["state", "city", "category_0"])
pivot_state_cat[["review_count", "stars"]]
# Out:
#                                    review_count     stars
# state city            category_0
# NV    Henderson       Bars           171.000000  3.000000
#                       Restaurants    102.454545  3.181818
#       Las Vegas       Bars            15.500000  4.000000
#                       Restaurants    221.153846  3.153846
#       North Las Vegas Bars             7.000000  3.500000
#                       Restaurants     12.000000  3.000000
# PA    Bellevue        Restaurants     14.000000  3.916667
#       Braddock        Bars            26.000000  4.500000
#       Carnegie        Bars            16.500000  4.000000
#                       Restaurants     26.000000  3.125000
#       Homestead       Bars            23.000000  2.500000
#                       Restaurants      6.000000  2.500000
#       Mc Kees Rocks   Bars             9.000000  3.500000
#                       Restaurants      7.333333  3.333333
#       Munhall         Restaurants      9.500000  3.500000
#       Pittsburgh      Bars            20.000000  3.416667
#                       Restaurants     67.000000  3.203704
#       West Homestead  Bars            92.000000  2.500000
#       West Mifflin    Restaurants      5.000000  4.333333

# %%
import numpy as np

# %%
pivot_agg = pd.pivot_table(
    df, index= ['state', 'take_out'],
    values= ['review_count'],
    aggfunc= [np.sum]
)

pivot_agg
# Out:
#                         sum
#                review_count
# state take_out
# NV    False            3921
#       True             8035
# PA    False            2015
#       True             6292

# %%
pivot_a2 = pd.pivot_table(
    df, index= ['state', 'city'],
    columns= ['take_out'],
    aggfunc= {'review_count': np.sum, 'stars': np.average}
    
)

pivot_a2
# Out:
#                       review_count           stars
# take_out                     False  True     False      True
# state city
# NV    Henderson               2009  2323  3.469697  3.258065
#       Las Vegas               1619  5607  3.423077  3.310345
#       North Las Vegas          293   105  3.155172  2.562500
# PA    Bellevue                  52   106  3.750000  3.750000
#       Braddock                   3    26  5.000000  4.500000
#       Carnegie                  74   225  3.269231  3.722222
#       Homestead                323   630  3.416667  2.909091
#       Mc Kees Rocks             48    59  3.666667  3.714286
#       Mount Lebanon             13    12  3.000000  3.500000
#       Munhall                   12    79  3.000000  3.000000
#       Pittsburgh              1447  5023  3.836364  3.566265
#       West Homestead             7   117  4.500000  2.750000
#       West Mifflin              36    15  3.500000  4.333333

# %%
import matplotlib.pyplot as plt

# %%
df_pitt = df[df['city'] == 'Pittsburgh']

df_pitt.head()
# Out:
#                                               name            category_0  \
# 95                             Aamco Transmissions           Auto Repair
# 96  Animal Rescue League Shelter & Wildlife Center       Animal Shelters
# 97                          Aracri's Greentree Inn               Italian
# 98                           Atch-Mont Real Estate  Real Estate Services
# 99                              Atria's Restaurant        American (New)
#
#              category_1  take_out  review_count  stars  city_id  state_id  \
# 95           Automotive     False            21    4.5        8         1
# 96        Veterinarians     False            43    4.0        8         1
# 97       American (New)      True            15    3.5        8         1
# 98  Property Management     False             3    2.0        8         1
# 99           Sandwiches      True            69    3.0        8         1
#
#           city state         rating
# 95  Pittsburgh    PA  9.0 out of 10
# 96  Pittsburgh    PA  8.0 out of 10
# 97  Pittsburgh    PA  7.0 out of 10
# 98  Pittsburgh    PA  4.0 out of 10
# 99  Pittsburgh    PA  6.0 out of 10

# %%
df_vegas = df[df['city'] == 'Las Vegas']

df_vegas.head()
# Out:
#                               name          category_0  \
# 430          Reliable Tax Services  Financial Services
# 431  Paradise Electro Stimulations            Shopping
# 432                     The Studio            Shopping
# 433                   Boomer's Bar                Bars
# 434                   Omelet House  Breakfast & Brunch
#
#                  category_1  take_out  review_count  stars  city_id  state_id  \
# 430             Accountants     False             3    4.5       12         2
# 431                   Adult     False             4    4.5       12         2
# 432                   Adult     False             7    5.0       12         2
# 433  American (Traditional)     False            19    3.5       12         2
# 434  American (Traditional)      True           703    4.5       12         2
#
#           city state          rating
# 430  Las Vegas    NV   9.0 out of 10
# 431  Las Vegas    NV   9.0 out of 10
# 432  Las Vegas    NV  10.0 out of 10
# 433  Las Vegas    NV   7.0 out of 10
# 434  Las Vegas    NV   9.0 out of 10

# %%
pitt_stars = df_pitt['stars']
pitt_stars.head()
# Out:
# 95    4.5
# 96    4.0
# 97    3.5
# 98    2.0
# 99    3.0
# Name: stars, dtype: float64

# %%
vegas_stars = df_vegas['stars']
vegas_stars.head()
# Out:
# 430    4.5
# 431    4.5
# 432    5.0
# 433    3.5
# 434    4.5
# Name: stars, dtype: float64

# %%
plt.hist(
    pitt_stars,
    alpha= 0.3,
    color= 'yellow',
    label= 'Pittsburgh',
    bin = 'auto'
)

plt.hist(
    vegas_stars,
    alpha= 0.3,
    color= 'red',
    label= 'Las Vegas',
    bin = 'auto'
)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/alexbui/Documents/GitHub/python/coursera/UPenn_yelp.ipynb Cell 46' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/alexbui/Documents/GitHub/python/coursera/UPenn_yelp.ipynb#ch0000044?line=0'>1</a> plt.hist(
#       <a href='vscode-notebook-cell:/Users/alexbui/Documents/GitHub/python/coursera/UPenn_yelp.ipynb#ch0000044?line=1'>2</a>     pitt_stars,
#       <a href='vscode-notebook-cell:/Users/alexbui/Documents/GitHub/python/coursera/UPenn_yelp.ipynb#ch0000044?line=2'>3</a>     alpha= 0.3,
#       <a href='vscode-notebook-cell:/Users/alexbui/Documents/GitHub/python/coursera/UPenn_yelp.ipynb#ch0000044?line=3'>4</a>     color= 'yellow',
#       <a href='vscode-notebook-cell:/Users/alexbui/Documents/GitHub/python/coursera/UPenn_yelp.ipynb#ch0000044?line=4'>5</a>     label= 'Pittsburgh',
#       <a href='vscode-notebook-cell:/Users/alexbui/Documents/GitHub/python/coursera/UPenn_yelp.ipynb#ch0000044?line=5'>6</a>     bin = 'auto'
#       <a href='vscode-notebook-cell:/Users/alexbui/Documents/GitHub/python/coursera/UPenn_yelp.ipynb#ch0000044?line=6'>7</a> )
#       <a href='vscode-notebook-cell:/Users/alexbui/Documents/GitHub/python/coursera/UPenn_yelp.ipynb#ch0000044?line=8'>9</a> plt.hist(
#      <a href='vscode-notebook-cell:/Users/alexbui/Documents/GitHub/python/coursera/UPenn_yelp.ipynb#ch0000044?line=9'>10</a>     vegas_stars,
#      <a href='vscode-notebook-cell:/Users/alexbui/Documents/GitHub/python/coursera/UPenn_yelp.ipynb#ch0000044?line=10'>11</a>     alpha= 0.3,
#    (...)
#      <a href='vscode-notebook-cell:/Users/alexbui/Documents/GitHub/python/coursera/UPenn_yelp.ipynb#ch0000044?line=13'>14</a>     bin = 'auto'
#      <a href='vscode-notebook-cell:/Users/alexbui/Documents/GitHub/python/coursera/UPenn_yelp.ipynb#ch0000044?line=14'>15</a> )
#      <a href='vscode-notebook-cell:/Users/alexbui/Documents/GitHub/python/coursera/UPenn_yelp.ipynb#ch0000044?line=16'>17</a> plt.show()
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/pyplot.py:2602, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/pyplot.py?line=2595'>2596</a> @_copy_docstring_and_deprecators(Axes.hist)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/pyplot.py?line=2596'>2597</a> def hist(
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/pyplot.py?line=2597'>2598</a>         x, bins=None, range=None, density=False, weights=None,
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/pyplot.py?line=2598'>2599</a>         cumulative=False, bottom=None, histtype='bar', align='mid',
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/pyplot.py?line=2599'>2600</a>         orientation='vertical', rwidth=None, log=False, color=None,
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/pyplot.py?line=2600'>2601</a>         label=None, stacked=False, *, data=None, **kwargs):
# -> <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/pyplot.py?line=2601'>2602</a>     return gca().hist(
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/pyplot.py?line=2602'>2603</a>         x, bins=bins, range=range, density=density, weights=weights,
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/pyplot.py?line=2603'>2604</a>         cumulative=cumulative, bottom=bottom, histtype=histtype,
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/pyplot.py?line=2604'>2605</a>         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/pyplot.py?line=2605'>2606</a>         color=color, label=label, stacked=stacked,
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/pyplot.py?line=2606'>2607</a>         **({"data": data} if data is not None else {}), **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/__init__.py?line=1408'>1409</a> @functools.wraps(func)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/__init__.py?line=1409'>1410</a> def inner(ax, *args, data=None, **kwargs):
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/__init__.py?line=1410'>1411</a>     if data is None:
# -> <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/__init__.py?line=1411'>1412</a>         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/__init__.py?line=1413'>1414</a>     bound = new_sig.bind(ax, *args, **kwargs)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/__init__.py?line=1414'>1415</a>     auto_label = (bound.arguments.get(label_namer)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/__init__.py?line=1415'>1416</a>                   or bound.kwargs.get(label_namer))
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/axes/_axes.py:6787, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/axes/_axes.py?line=6784'>6785</a> if patch:
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/axes/_axes.py?line=6785'>6786</a>     p = patch[0]
# -> <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/axes/_axes.py?line=6786'>6787</a>     p.update(kwargs)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/axes/_axes.py?line=6787'>6788</a>     if lbl is not None:
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/axes/_axes.py?line=6788'>6789</a>         p.set_label(lbl)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/artist.py:1064, in Artist.update(self, props)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/artist.py?line=1061'>1062</a>             func = getattr(self, f"set_{k}", None)
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/artist.py?line=1062'>1063</a>             if not callable(func):
# -> <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/artist.py?line=1063'>1064</a>                 raise AttributeError(f"{type(self).__name__!r} object "
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/artist.py?line=1064'>1065</a>                                      f"has no property {k!r}")
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/artist.py?line=1065'>1066</a>             ret.append(func(v))
#    <a href='file:///Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/matplotlib/artist.py?line=1066'>1067</a> if ret:
#
# AttributeError: 'Rectangle' object has no property 'bin'
