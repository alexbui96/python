# %%
import numpy as np
import pandas as pd
import os

# %%
df = pd.read_csv(os.getcwd() + '/data/' + 'Cartwheeldata.csv')
df.head()
# Out:
#    ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0   1   56      F            1       Y             1    62.0      61.0
# 1   2   26      F            1       Y             1    62.0      60.0
# 2   3   33      F            1       Y             1    66.0      64.0
# 3   4   39      F            1       N             0    64.0      63.0
# 4   5   27      M            2       N             0    73.0      75.0
#
#    CWDistance Complete  CompleteGroup  Score
# 0          79        Y              1      7
# 1          70        Y              1      8
# 2          85        Y              1      7
# 3          87        Y              1     10
# 4          72        N              0      4

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'GenderGroup', 'Glasses', 'GlassesGroup',
#        'Height', 'Wingspan', 'CWDistance', 'Complete', 'CompleteGroup',
#        'Score'],
#       dtype='object')

# %%
# Return all observation of CWDistance

df.loc[:,'CWDistance']
# Out:
# 0      79
# 1      70
# 2      85
# 3      87
# 4      72
# 5      81
# 6     107
# 7      98
# 8     106
# 9      65
# 10     96
# 11     79
# 12     92
# 13     66
# 14     72
# 15    115
# 16     90
# 17     74
# 18     64
# 19     85
# 20     66
# 21    101
# 22     82
# 23     63
# 24     67
# Name: CWDistance, dtype: int64

# %%
# Select all rows for multiple columns, ["CWDistance", "Height", "Wingspan"]
df.loc[:,["CWDistance", "Height", "Wingspan"]]
# Out:
#     CWDistance  Height  Wingspan
# 0           79   62.00      61.0
# 1           70   62.00      60.0
# 2           85   66.00      64.0
# 3           87   64.00      63.0
# 4           72   73.00      75.0
# 5           81   75.00      71.0
# 6          107   75.00      76.0
# 7           98   65.00      62.0
# 8          106   74.00      73.0
# 9           65   63.00      60.0
# 10          96   69.50      66.0
# 11          79   62.75      58.0
# 12          92   65.00      64.5
# 13          66   61.50      57.5
# 14          72   73.00      74.0
# 15         115   71.00      72.0
# 16          90   61.50      59.5
# 17          74   66.00      66.0
# 18          64   70.00      69.0
# 19          85   68.00      66.0
# 20          66   69.00      67.0
# 21         101   71.00      70.0
# 22          82   70.00      68.0
# 23          63   69.00      71.0
# 24          67   65.00      63.0

# %%
# Select range of rows for all columns
df.loc[10:15]
# Out:
#     ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 10  11   30      M            2       Y             1   69.50      66.0
# 11  12   28      F            1       Y             1   62.75      58.0
# 12  13   25      F            1       Y             1   65.00      64.5
# 13  14   23      F            1       N             0   61.50      57.5
# 14  15   31      M            2       Y             1   73.00      74.0
# 15  16   26      M            2       Y             1   71.00      72.0
#
#     CWDistance Complete  CompleteGroup  Score
# 10          96        Y              1      6
# 11          79        Y              1     10
# 12          92        Y              1      6
# 13          66        Y              1      4
# 14          72        Y              1      9
# 15         115        Y              1      6

# %%
# Select first 9 rows of CWDistance
df.loc[:9, "CWDistance"]
# Out:
# 0     79
# 1     70
# 2     85
# 3     87
# 4     72
# 5     81
# 6    107
# 7     98
# 8    106
# 9     65
# Name: CWDistance, dtype: int64

# %%
# Select first 4 rows for all columns
df.iloc[:4]
# Out:
#    ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0   1   56      F            1       Y             1    62.0      61.0
# 1   2   26      F            1       Y             1    62.0      60.0
# 2   3   33      F            1       Y             1    66.0      64.0
# 3   4   39      F            1       N             0    64.0      63.0
#
#    CWDistance Complete  CompleteGroup  Score
# 0          79        Y              1      7
# 1          70        Y              1      8
# 2          85        Y              1      7
# 3          87        Y              1     10

# %%
# Select row 1-4 and column 2-3 (start index 0)

df.iloc[1:5, 2:4]
# Out:
#   Gender  GenderGroup
# 1      F            1
# 2      F            1
# 3      F            1
# 4      M            2

# %%
# Data type
df.dtypes
# Out:
# ID                 int64
# Age                int64
# Gender            object
# GenderGroup        int64
# Glasses           object
# GlassesGroup       int64
# Height           float64
# Wingspan         float64
# CWDistance         int64
# Complete          object
# CompleteGroup      int64
# Score              int64
# dtype: object

# %%
# List unique values in the df['Gender'] column
df.Gender.unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
# List unique values in the df['GenderGroup'] column
df.GenderGroup.unique()
# Out:
# array([1, 2], dtype=int64)

# %%
# Specify a list of mulitple column
df.loc[:,["Gender", "GenderGroup"]]
# Out:
#    Gender  GenderGroup
# 0       F            1
# 1       F            1
# 2       F            1
# 3       F            1
# 4       M            2
# 5       M            2
# 6       M            2
# 7       F            1
# 8       M            2
# 9       F            1
# 10      M            2
# 11      F            1
# 12      F            1
# 13      F            1
# 14      M            2
# 15      M            2
# 16      F            1
# 17      M            2
# 18      M            2
# 19      F            1
# 20      M            2
# 21      M            2
# 22      M            2
# 23      M            2
# 24      F            1

# %%
# Combinations type
df.groupby(['Gender','GenderGroup']).size()
# Out:
# Gender  GenderGroup
# F       1              12
# M       2              13
# dtype: int64

# %%
da = pd.read_csv(os.getcwd() + '/data/' +'nhanes_2015_2016.csv')
da.head()
# Out:
#     SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0  83732     1.0     NaN     1.0       1         1        62         3
# 1  83733     1.0     NaN     6.0       1         1        53         3
# 2  83734     1.0     NaN     NaN       1         1        78         3
# 3  83735     2.0     1.0     1.0       2         2        56         3
# 4  83736     2.0     1.0     1.0       2         2        42         4
#
#    DMDCITZN  DMDEDUC2  ...  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# 0       1.0       5.0  ...   124.0    64.0   94.8  184.5    27.8    43.3
# 1       2.0       3.0  ...   140.0    88.0   90.4  171.4    30.8    38.0
# 2       1.0       3.0  ...   132.0    44.0   83.4  170.1    28.8    35.6
# 3       1.0       5.0  ...   134.0    68.0  109.8  160.9    42.4    38.5
# 4       1.0       4.0  ...   114.0    54.0   55.2  164.9    20.3    37.4
#
#    BMXARML  BMXARMC  BMXWAIST  HIQ210
# 0     43.6     35.9     101.1     2.0
# ...

# %%
# number of rows and columns
da.shape
# Out:
# (5735, 28)

# %%
da.dtypes
# Out:
# SEQN          int64
# ALQ101      float64
# ALQ110      float64
# ALQ130      float64
# SMQ020        int64
# RIAGENDR      int64
# RIDAGEYR      int64
# RIDRETH1      int64
# DMDCITZN    float64
# DMDEDUC2    float64
# DMDMARTL    float64
# DMDHHSIZ      int64
# WTINT2YR    float64
# SDMVPSU       int64
# SDMVSTRA      int64
# INDFMPIR    float64
# BPXSY1      float64
# BPXDI1      float64
# BPXSY2      float64
# BPXDI2      float64
# BMXWT       float64
# BMXHT       float64
# BMXBMI      float64
# BMXLEG      float64
# BMXARML     float64
# BMXARMC     float64
# BMXWAIST    float64
# HIQ210      float64
# dtype: object

# %%
# DMDEDUC2 column
dmdeduc2 = da["DMDEDUC2"]

# %%
# row 3 from data set
r3 = da.iloc[3, :]

# %%
# row 3,4 
r3_4 = da.iloc[3:5, :]

# %%
# column 2-4
c2_4 = da.iloc[:, 2:5]

# %%
# missing data
pd.isnull(da.DMDEDUC2).sum()
# Out:
# 261

# %%
# complete data
pd.notnull(da.DMDEDUC2).sum()
# Out:
# 5474

# %%
# generate list and for loop

result = []

for x in range(10):
    for y in range(5):
        if x*y > 10:
            result.append((x, y))
            
print(result)
# Out:
# [(3, 4), (4, 3), (4, 4), (5, 3), (5, 4), (6, 2), (6, 3), (6, 4), (7, 2), (7, 3), (7, 4), (8, 2), (8, 3), (8, 4), (9, 2), (9, 3), (9, 4)]
